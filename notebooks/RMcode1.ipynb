# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\songu\Downloads\archive (1)\orders.csv")
df1 = pd.read_csv(r"C:\Users\songu\Downloads\archive (1)\products.csv")
df2 = pd.read_csv(r"C:\Users\songu\Downloads\archive (1)\order_products__prior.csv")
df3 = pd.read_csv(r"C:\Users\songu\Downloads\archive (1)\departments.csv")
df4 = pd.read_csv(r"C:\Users\songu\Downloads\archive (1)\aisles.csv")
df5 = pd.read_csv(r"C:\Users\songu\Downloads\archive (1)\order_products__train.csv")

# %%
#prior data
dfp = df2.merge(df, on = "order_id")
dfp = dfp.merge(df1, on = 'product_id')
dfp = dfp.merge(df3, on = "department_id")
dfp = dfp.merge(df4, on = "aisle_id")
dfp
# Out:
#           order_id  product_id  add_to_cart_order  reordered  user_id  \
# 0                2       33120                  1          1   202279
# 1                2       28985                  2          1   202279
# 2                2        9327                  3          0   202279
# 3                2       45918                  4          1   202279
# 4                2       30035                  5          0   202279
# ...            ...         ...                ...        ...      ...
# 32434484   3421083       39678                  6          1    25247
# 32434485   3421083       11352                  7          0    25247
# 32434486   3421083        4600                  8          0    25247
# 32434487   3421083       24852                  9          1    25247
# 32434488   3421083        5020                 10          1    25247
#
#          eval_set  order_number  order_dow  order_hour_of_day  \
# 0           prior             3          5                  9
# 1           prior             3          5                  9
# 2           prior             3          5                  9
# 3           prior             3          5                  9
# 4           prior             3          5                  9
# ...           ...           ...        ...                ...
# 32434484    prior            24          2                  6
# 32434485    prior            24          2                  6
# 32434486    prior            24          2                  6
# 32434487    prior            24          2                  6
# 32434488    prior            24          2                  6
#
#           days_since_prior_order  \
# 0                            8.0
# 1                            8.0
# 2                            8.0
# 3                            8.0
# 4                            8.0
# ...                          ...
# 32434484                    21.0
# 32434485                    21.0
# 32434486                    21.0
# 32434487                    21.0
# 32434488                    21.0
#
#                                                product_name  aisle_id  \
# 0                                        Organic Egg Whites        86
# 1                                     Michigan Organic Kale        83
# 2                                             Garlic Powder       104
# 3                                            Coconut Butter        19
# 4                                         Natural Sweetener        17
# ...                                                     ...       ...
# 32434484          Free & Clear Natural Dishwasher Detergent        74
# 32434485       Organic Mini Sandwich Crackers Peanut Butter        78
# 32434486                    All Natural French Toast Sticks        52
# 32434487                                             Banana        24
# 32434488  Organic  Sweet & Salty Peanut Pretzel Granola ...         3
#
#           department_id  department                aisle
# 0                    16  dairy eggs                 eggs
# 1                     4     produce     fresh vegetables
# 2                    13      pantry    spices seasonings
# 3                    13      pantry        oils vinegars
# 4                    13      pantry   baking ingredients
# ...                 ...         ...                  ...
# 32434484             17   household      dish detergents
# 32434485             19      snacks             crackers
# 32434486              1      frozen     frozen breakfast
# 32434487              4     produce         fresh fruits
# 32434488             19      snacks  energy granola bars
#
# [32434489 rows x 15 columns]

# %%
#training data
dft = df5.merge(df, on = "order_id")
dft = dft.merge(df1, on = 'product_id')
dft = dft.merge(df3, on = "department_id")
dft = dft.merge(df4, on = "aisle_id")
dft
# Out:
#          order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0               1       49302                  1          1   112108    train
# 1               1       11109                  2          1   112108    train
# 2               1       10246                  3          0   112108    train
# 3               1       49683                  4          0   112108    train
# 4               1       43633                  5          1   112108    train
# ...           ...         ...                ...        ...      ...      ...
# 1384612   3421063       14233                  3          1   169679    train
# 1384613   3421063       35548                  4          1   169679    train
# 1384614   3421070       35951                  1          1   139822    train
# 1384615   3421070       16953                  2          1   139822    train
# 1384616   3421070        4724                  3          1   139822    train
#
#          order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0                   4          4                 10                     9.0
# 1                   4          4                 10                     9.0
# 2                   4          4                 10                     9.0
# 3                   4          4                 10                     9.0
# 4                   4          4                 10                     9.0
# ...               ...        ...                ...                     ...
# 1384612            30          0                 10                     4.0
# 1384613            30          0                 10                     4.0
# 1384614            15          6                 10                     8.0
# 1384615            15          6                 10                     8.0
# 1384616            15          6                 10                     8.0
#
#                                           product_name  aisle_id  \
# 0                                     Bulgarian Yogurt       120
# 1        Organic 4% Milk Fat Whole Milk Cottage Cheese       108
# 2                                Organic Celery Hearts        83
# 3                                       Cucumber Kirby        83
# 4                 Lightly Smoked Sardines in Olive Oil        95
# ...                                                ...       ...
# 1384612                         Natural Artesian Water       115
# 1384613                           Twice Baked Potatoes        13
# 1384614                Organic Unsweetened Almond Milk        91
# 1384615                           Creamy Peanut Butter        88
# 1384616                             Broccoli Florettes        32
#
#          department_id    department                          aisle
# 0                   16    dairy eggs                         yogurt
# 1                   16    dairy eggs           other creams cheeses
# 2                    4       produce               fresh vegetables
# 3                    4       produce               fresh vegetables
# 4                   15  canned goods            canned meat seafood
# ...                ...           ...                            ...
# 1384612              7     beverages  water seltzer sparkling water
# 1384613             20          deli                 prepared meals
# 1384614             16    dairy eggs                soy lactosefree
# 1384615             13        pantry                        spreads
# 1384616              4       produce               packaged produce
#
# [1384617 rows x 15 columns]

# %%
dfp.info()
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 15 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   product_id              int64
#  2   add_to_cart_order       int64
#  3   reordered               int64
#  4   user_id                 int64
#  5   eval_set                object
#  6   order_number            int64
#  7   order_dow               int64
#  8   order_hour_of_day       int64
#  9   days_since_prior_order  float64
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           int64
#  13  department              object
#  14  aisle                   object
# dtypes: float64(1), int64(10), object(4)
# memory usage: 3.6+ GB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1384617 entries, 0 to 1384616
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   order_id                1384617 non-null  int64
#  1   product_id              1384617 non-null  int64
#  2   add_to_cart_order       1384617 non-null  int64
#  3   reordered               1384617 non-null  int64
#  4   user_id                 1384617 non-null  int64
#  5   eval_set                1384617 non-null  object
#  6   order_number            1384617 non-null  int64
#  7   order_dow               1384617 non-null  int64
#  8   order_hour_of_day       1384617 non-null  int64
#  9   days_since_prior_order  1384617 non-null  float64
#  10  product_name            1384617 non-null  object
#  11  aisle_id                1384617 non-null  int64
#  12  department_id           1384617 non-null  int64
#  13  department              1384617 non-null  object
#  14  aisle                   1384617 non-null  object
# dtypes: float64(1), int64(10), object(4)
# memory usage: 158.5+ MB

# %%
#Checking missing value in each column
print(dfp.isnull().sum())
print(dft.isnull().sum())
# Out:
# order_id                        0
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# user_id                         0
# eval_set                        0
# order_number                    0
# order_dow                       0
# order_hour_of_day               0
# days_since_prior_order    2078068
# product_name                    0
# aisle_id                        0
# department_id                   0
# department                      0
# aisle                           0
# dtype: int64
# order_id                  0
# product_id                0
# add_to_cart_order         0
# reordered                 0
# user_id                   0
# eval_set                  0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# product_name              0
# aisle_id                  0
# department_id             0
# department                0
# aisle                     0
# dtype: int64

# %%
#Checking percentage of missing value to decide whether I should drop the missing value
dfp.isnull().sum()/len(df)*100
# Out:
# order_id                   0.000000
# product_id                 0.000000
# add_to_cart_order          0.000000
# reordered                  0.000000
# user_id                    0.000000
# eval_set                   0.000000
# order_number               0.000000
# order_dow                  0.000000
# order_hour_of_day          0.000000
# days_since_prior_order    60.742987
# product_name               0.000000
# aisle_id                   0.000000
# department_id              0.000000
# department                 0.000000
# aisle                      0.000000
# dtype: float64

# %%
#The missing values ​​are due to the customer placing their first order. I will fill missing value as 0.
dfp['days_since_prior_order'].fillna(0, inplace = True)
dfp
# Out:
# C:\Users\songu\AppData\Local\Temp\ipykernel_47956\2693919308.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfp['days_since_prior_order'].fillna(0, inplace = True)
#           order_id  product_id  add_to_cart_order  reordered  user_id  \
# 0                2       33120                  1          1   202279
# 1                2       28985                  2          1   202279
# 2                2        9327                  3          0   202279
# 3                2       45918                  4          1   202279
# 4                2       30035                  5          0   202279
# ...            ...         ...                ...        ...      ...
# 32434484   3421083       39678                  6          1    25247
# 32434485   3421083       11352                  7          0    25247
# 32434486   3421083        4600                  8          0    25247
# 32434487   3421083       24852                  9          1    25247
# 32434488   3421083        5020                 10          1    25247
#
#          eval_set  order_number  order_dow  order_hour_of_day  \
# 0           prior             3          5                  9
# 1           prior             3          5                  9
# 2           prior             3          5                  9
# 3           prior             3          5                  9
# 4           prior             3          5                  9
# ...           ...           ...        ...                ...
# 32434484    prior            24          2                  6
# 32434485    prior            24          2                  6
# 32434486    prior            24          2                  6
# 32434487    prior            24          2                  6
# 32434488    prior            24          2                  6
#
#           days_since_prior_order  \
# 0                            8.0
# 1                            8.0
# 2                            8.0
# 3                            8.0
# 4                            8.0
# ...                          ...
# 32434484                    21.0
# 32434485                    21.0
# 32434486                    21.0
# 32434487                    21.0
# 32434488                    21.0
#
#                                                product_name  aisle_id  \
# 0                                        Organic Egg Whites        86
# 1                                     Michigan Organic Kale        83
# 2                                             Garlic Powder       104
# 3                                            Coconut Butter        19
# 4                                         Natural Sweetener        17
# ...                                                     ...       ...
# 32434484          Free & Clear Natural Dishwasher Detergent        74
# 32434485       Organic Mini Sandwich Crackers Peanut Butter        78
# 32434486                    All Natural French Toast Sticks        52
# 32434487                                             Banana        24
# 32434488  Organic  Sweet & Salty Peanut Pretzel Granola ...         3
#
#           department_id  department                aisle
# 0                    16  dairy eggs                 eggs
# 1                     4     produce     fresh vegetables
# 2                    13      pantry    spices seasonings
# 3                    13      pantry        oils vinegars
# 4                    13      pantry   baking ingredients
# ...                 ...         ...                  ...
# 32434484             17   household      dish detergents
# 32434485             19      snacks             crackers
# 32434486              1      frozen     frozen breakfast
# 32434487              4     produce         fresh fruits
# 32434488             19      snacks  energy granola bars
#
# [32434489 rows x 15 columns]

# %%
dfp.isnull().sum()
# Out:
# order_id                  0
# product_id                0
# add_to_cart_order         0
# reordered                 0
# user_id                   0
# eval_set                  0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# product_name              0
# aisle_id                  0
# department_id             0
# department                0
# aisle                     0
# dtype: int64

# %%
dfp.duplicated().sum()
# Out:
# np.int64(0)

# %%
users_count = dfm['user_id'].value_counts()
users_count
# Out:
# user_id
# 201268    3725
# 129928    3638
# 164055    3061
# 186704    2936
# 176478    2921
#           ...
# 205806       3
# 119135       3
# 92835        3
# 93161        3
# 98637        3
# Name: count, Length: 206209, dtype: int64

# %%
active = users_count[users_count > 5]
active
# Out:
# user_id
# 201268    3725
# 129928    3638
# 164055    3061
# 186704    2936
# 176478    2921
#           ...
# 4310         6
# 53675        6
# 139625       6
# 173944       6
# 189967       6
# Name: count, Length: 204741, dtype: int64

# %%
#Before that I only have the list. Now directly find active user on main data frame. 
dfp_active = dfp[dfp['user_id'].isin(active.index)]  #index is for choosing ID only
dfp_active
# Out:
#           order_id  product_id  add_to_cart_order  reordered  user_id  \
# 0                2       33120                  1          1   202279
# 1                2       28985                  2          1   202279
# 2                2        9327                  3          0   202279
# 3                2       45918                  4          1   202279
# 4                2       30035                  5          0   202279
# ...            ...         ...                ...        ...      ...
# 32434484   3421083       39678                  6          1    25247
# 32434485   3421083       11352                  7          0    25247
# 32434486   3421083        4600                  8          0    25247
# 32434487   3421083       24852                  9          1    25247
# 32434488   3421083        5020                 10          1    25247
#
#          eval_set  order_number  order_dow  order_hour_of_day  \
# 0           prior             3          5                  9
# 1           prior             3          5                  9
# 2           prior             3          5                  9
# 3           prior             3          5                  9
# 4           prior             3          5                  9
# ...           ...           ...        ...                ...
# 32434484    prior            24          2                  6
# 32434485    prior            24          2                  6
# 32434486    prior            24          2                  6
# 32434487    prior            24          2                  6
# 32434488    prior            24          2                  6
#
#           days_since_prior_order  \
# 0                            8.0
# 1                            8.0
# 2                            8.0
# 3                            8.0
# 4                            8.0
# ...                          ...
# 32434484                    21.0
# 32434485                    21.0
# 32434486                    21.0
# 32434487                    21.0
# 32434488                    21.0
#
#                                                product_name  aisle_id  \
# 0                                        Organic Egg Whites        86
# 1                                     Michigan Organic Kale        83
# 2                                             Garlic Powder       104
# 3                                            Coconut Butter        19
# 4                                         Natural Sweetener        17
# ...                                                     ...       ...
# 32434484          Free & Clear Natural Dishwasher Detergent        74
# 32434485       Organic Mini Sandwich Crackers Peanut Butter        78
# 32434486                    All Natural French Toast Sticks        52
# 32434487                                             Banana        24
# 32434488  Organic  Sweet & Salty Peanut Pretzel Granola ...         3
#
#           department_id  department                aisle
# 0                    16  dairy eggs                 eggs
# 1                     4     produce     fresh vegetables
# 2                    13      pantry    spices seasonings
# 3                    13      pantry        oils vinegars
# 4                    13      pantry   baking ingredients
# ...                 ...         ...                  ...
# 32434484             17   household      dish detergents
# 32434485             19      snacks             crackers
# 32434486              1      frozen     frozen breakfast
# 32434487              4     produce         fresh fruits
# 32434488             19      snacks  energy granola bars
#
# [32428249 rows x 15 columns]

# %%
interaction_matrix = dfp_active.pivot_table( 
    index = "user_id",
    columns = "product_id",
    values = "order_id",
    aggfunc = "count",
    fill_value = 0
)
# Out:
# C:\Users\songu\AppData\Local\Temp\ipykernel_47956\2074314116.py:1: PerformanceWarning: The following operation may generate 10170918657 cells in the resulting pandas object.
#   interaction_matrix = dfp_active.pivot_table(
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 interaction_matrix = dfp_active.pivot_table(
#       2     index = "user_id",
#       3     columns = "product_id",
#       4     values = "order_id",
#       5     aggfunc = "count",
#       6     fill_value = 0
#       7 )
#
# File c:\Users\songu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9516, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9499 @Substitution("")
#    9500 @Appender(_shared_docs["pivot_table"])
#    9501 def pivot_table(
#    (...)   9512     sort: bool = True,
#    9513 ) -> DataFrame:
#    9514     from pandas.core.reshape.pivot import pivot_table
# -> 9516     return pivot_table(
#    9517         self,
#    9518         values=values,
#    9519         index=index,
#    9520         columns=columns,
#    9521         aggfunc=aggfunc,
#    9522         fill_value=fill_value,
#    9523         margins=margins,
#    9524         dropna=dropna,
#    9525         margins_name=margins_name,
#    9526         observed=observed,
#    9527         sort=sort,
#    9528     )
#
# File c:\Users\songu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File c:\Users\songu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\pivot.py:203, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     201         else:
#     202             to_unstack.append(name)
# --> 203     table = agged.unstack(to_unstack, fill_value=fill_value)
#     205 if not dropna:
#     206     if isinstance(table.index, MultiIndex):
#
# File c:\Users\songu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9935, in DataFrame.unstack(self, level, fill_value, sort)
#    9871 """
#    9872 Pivot a level of the (necessarily hierarchical) index labels.
#    9873
#    (...)   9931 dtype: float64
#    9932 """
#    9933 from pandas.core.reshape.reshape import unstack
# -> 9935 result = unstack(self, level, fill_value, sort)
#    9937 return result.__finalize__(self, method="unstack")
#
# File c:\Users\songu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\reshape.py:504, in unstack(obj, level, fill_value, sort)
#     502 if isinstance(obj, DataFrame):
#     503     if isinstance(obj.index, MultiIndex):
# --> 504         return _unstack_frame(obj, level, fill_value=fill_value, sort=sort)
#     505     else:
#     506         return obj.T.stack(future_stack=True)
#
# File c:\Users\songu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\reshape.py:537, in _unstack_frame(obj, level, fill_value, sort)
#     535     return obj._constructor_from_mgr(mgr, axes=mgr.axes)
#     536 else:
# --> 537     return unstacker.get_result(
#     538         obj._values, value_columns=obj.columns, fill_value=fill_value
#     539     )
#
# File c:\Users\songu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\reshape.py:238, in _Unstacker.get_result(self, values, value_columns, fill_value)
#     235 if value_columns is None and values.shape[1] != 1:  # pragma: no cover
#     236     raise ValueError("must pass column labels for multi-column data")
# --> 238 values, _ = self.get_new_values(values, fill_value)
#     239 columns = self.get_new_columns(value_columns)
#     240 index = self.new_index
#
# File c:\Users\songu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\reshape.py:289, in _Unstacker.get_new_values(self, values, fill_value)
#     287     else:
#     288         dtype, fill_value = maybe_promote(dtype, fill_value)
# --> 289         new_values = np.empty(result_shape, dtype=dtype)
#     290         new_values.fill(fill_value)
#     292 name = dtype.name
#
# MemoryError: Unable to allocate 75.8 GiB for an array with shape (204741, 49677) and data type int64
